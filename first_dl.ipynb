# %% [markdown]
# <a href="https://colab.research.google.com/github/meenalsankar/CodeAlpha_Sales-Prediction-using-Python/blob/main/first_dl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
